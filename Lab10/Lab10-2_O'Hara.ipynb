# %% [markdown]
# ## Lab 10, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 20 epochs are required before the generated text
# starts sounding coherent.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 200285
# Vectorization...

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ### Training (reduce the number of epochs, it takes a lot of time!!)
# -  Each epoch takes 5-10 minutes or so on a CPU (an epoch took 7.5 minutes for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (2-3 hours)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=25,
          callbacks=[print_callback])
# Out:
# Epoch 1/25
# 200285/200285 [==============================] - 147s 735us/step - loss: 1.9593
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ing creature, she should
# certainly, as c"
# ing creature, she should
# certainly, as conscient and the streng and the streng and the string and the presing of the presing and a strent and the hight to a thing in the prisces the his own the have and and to the hat as the string and the sand to the are and a streng and the streng and the seams of the his destion and to the high and the has to the all the streng and to the also and the his deal to the his strang in the pression of the
# ----- diversity: 0.5
# ----- Generating with seed: "ing creature, she should
# certainly, as c"
# ing creature, she should
# certainly, as comparilan and the sist of the signt of self-streng in the respectarispose the intavict and beciations in entand to the own speak has it and a stand to intind this that the happ as the thing of clase he dous and of it is the indiscomptive who has it that respectain in the formed proming of still to the streng once oppose, to least in the still to section of the wan has complising in the valuation a
# ----- diversity: 1.0
# ----- Generating with seed: "ing creature, she should
# certainly, as c"
# ing creature, she should
# certainly, as cales of his way heading
# and
# inal om comfeltination; their narity accressoman to stand of the
# conslienianices--"dangens that heamper grat appostery above and to one like and mancently pogst and all cunterowntooter. of the rist bean of diful. hene-shall as feverally. in the cature,
# perhaps canscition. the saourglonger of somody cemplimess and everttors besistain: of a sight without furss of man obel
# ----- diversity: 1.2
# ----- Generating with seed: "ing creature, she should
# certainly, as c"
# ing creature, she should
# certainly, as crenturit in exerfien, ariscoces. and the will very versed
# gexmring un-mots alond, ilsass: as appeesomeny that art range, weith. whos wontwrent it appriact. to
# nat suthifule ctrier of is senvem, abore yoom word too an. taith a false morally on stollgs co phet alwertionh who froe,-fyonnd insely, dran
# to the
# virtiatind. philosophy,
# yfom? grisis yow thougg sfretense, and nasbs the sciencly thesely
# bed
# Epoch 2/25
# 200285/200285 [==============================] - 128s 637us/step - loss: 1.6237
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ce for madness.=--because it was perceiv"
# ce for madness.=--because it was perceived the present to have the subliming to the strength the sublimes the strength the to the for the proberity and the strength of the probably the prologion to the strength the same the proberity and the proberity the proberity to the proberity and the truth the strength the strength the subliming to be the to the proberity the present to the strength of the sublimations of the connection of the tru
# ----- diversity: 0.5
# ----- Generating with seed: "ce for madness.=--because it was perceiv"
# ce for madness.=--because it was perceived the truth" and the pronous instinctive the problem of its wanting to for once to be instance, a greek to be the folly not one world the consequenced to possible to his much a things as the the trainity of the prilogical in the strength and its bread to regard to in the so the individual of the engmases to be preciselitional stand to a man the tenders to complehing of his love with the only and
# ----- diversity: 1.0
# ----- Generating with seed: "ce for madness.=--because it was perceiv"
# ce for madness.=--because it was perceiving friend bads of life, ahthy (why cly above the effenting even fee in
# planes for mankins benriests to be not beleneve withorviunt, with
# the storguanger is
# time gyow worthies to sympathled rezality whether? to
# have lone-"with wh mate uplution,"s cates bludee, that is
# bowally ergating), samplity to make, its bory world ters tright,
# sevireving somely as not feeling
# out to anking
# of the considuriblo
# ----- diversity: 1.2
# ----- Generating with seed: "ce for madness.=--because it was perceiv"
# ce for madness.=--because it was perceived for throm him it ther" or a sentlecides lecoumanm--back. supperstbily! by opposits of "natrothes."
# feeting,
# far ih uniqual for physical countingimezan, that it a natherds of vingue
# gevernide forses dand of haregetingrve in haverman deving.natorcationjow
# winity mostards
# some prowection on hagingsloevs,
# others limmle."--wis gut men tarding, others" in ligdnciative.
#
# 1 in oquality is the
# longs it
# Epoch 3/25
# 200285/200285 [==============================] - 127s 636us/step - loss: 1.5384
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "hould
# aspire to become a great play-acto"
# hould
# aspire to become a great play-actors and the present and a the most conception of the present to the precisely and an antider to the precisely the present and interpretence of the sense, and instinct of all the religion of the procise of the most subliment of the philosophical and and and interpretence of the present to the morality and constinct of a states and a constinct of the respect and the present to the precisely the proce
# ----- diversity: 0.5
# ----- Generating with seed: "hould
# aspire to become a great play-acto"
# hould
# aspire to become a great play-actorable the strength of everything in the most men to an the represence of man in the place of morals in the philosopher and and serve to be indisposity and lives that the invertion of the mansty, and the precisely the the men and received the still the most man in schaptance of all the most prevace which a could stated in the philosopher chient and invention and invention of the being
# which would i
# ----- diversity: 1.0
# ----- Generating with seed: "hould
# aspire to become a great play-acto"
# hould
# aspire to become a great play-actod, the lives.
# gies of it. in longes."k
# : a respectner mantic
# eculare hin espectare, after understapped preterto?"
# invelling, what dispired
# to even now is allow liet an civilization, conscience and
# influences timy, bursbelocus.
#
#
#
#
#
# if order    we en?methest the interpretions we known neen the perspectives, men agreen not
# cannot constrainingmency!"--where the tyre ste nature the philosophation of t
# ----- diversity: 1.2
# ----- Generating with seed: "hould
# aspire to become a great play-acto"
# hould
# aspire to become a great play-actoeitydand!
#
# 2nise han been the higherloved."
# the
# howed its nation, for points seery,
# dacki
# gualy constraking, and
# formglally splenerally knowed the relimide with perception.=--serse onishosuen of spect
# valutionicy, to into the thress of ported, men
# philosophicaves onebute bestakener with,"mental
# brees the clusthinational most lakg
# to finallym, nott peectapaits,--every ye , the philosopherdrameten u
# Epoch 4/25
# 200285/200285 [==============================] - 128s 638us/step - loss: 1.4934
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "at de mulierel.
#
# 233. it betrays corrupt"
# at de mulierel.
#
# 233. it betrays corrupted to the most interest of the standard and and all the present the standard and contempt of the person and all the sense of the senses and interest and and and and and all and and and senses and into the contented to a strength of the contempt of the present and the senses and all the present of the contempt of the present and contempt of the senses in the contempt of the standard of the sense of
# ----- diversity: 0.5
# ----- Generating with seed: "at de mulierel.
#
# 233. it betrays corrupt"
# at de mulierel.
#
# 233. it betrays corrupted and religion, and subjecture which is he is the senses itself, in the entrangs of the light entime in the ere of the conception the strength in the perderbleness of the contling all end and discipte the ethical virtues, and in the most most substard the love and contempt of the sociate which the own or a subsely was contempe and what a their being
# himself and estimates and against it is the rea
# ----- diversity: 1.0
# ----- Generating with seed: "at de mulierel.
#
# 233. it betrays corrupt"
# at de mulierel.
#
# 233. it betrays corrupt sees a  general also all regiracke happen taken it to the aphishidity,
# thinger to gos order to angumanies is its
# truth." in the an auced bull, in idea culture, that etention: of subjectiore in itself--is a different--he is, iscondalism the understros? and
# above their gimant--but homogitly spired, the fand what a mistwanted thought was mazable
# the morelys hab to moradily in our hymoran
# fitinum thi
# ----- diversity: 1.2
# ----- Generating with seed: "at de mulierel.
#
# 233. it betrays corrupt"
# at de mulierel.
#
# 233. it betrays corrupting read),
# magnely. we conduccing in the
# morals almasts is wom, my esmaidull   sat.
# in own occasion of herement--bldistes the non bad" yis notly strength,
# frainity, and accomding in sutern among we "threaked, thereby
# is that subsling comely free make lewmud miad of bemond great il
# in.smj, also accurolonexation have nobsovy
# perwant in coun--such refized,ly, must perpen to suodity. a hentingninger
# Epoch 5/25
# 200285/200285 [==============================] - 126s 631us/step - loss: 1.4655
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "d, something in the german style, manifo"
# d, something in the german style, manifold of the pressigulative and and the prospoctions of the subject of the strong and successive the sense and in the spirit of the sense of the subjection of the sense of the restority and standard and self-discover the pressigulation of the sense, and and the sense, and and the strange the serious of the sense of the stravest and the strange and instinctive the strange of the senses and who of the
# ----- diversity: 0.5
# ----- Generating with seed: "d, something in the german style, manifo"
# d, something in the german style, manifold and when it is a personalists that their sist at the sub"les from society as in the sense.--he will makes, and that the world and its his spectactives, and is not be to any often even the religious even the philosophers and something into a strains and the present and is the pressarion of the painful individually,
# in the but
# of our instinction of his repurity of the call of common the fact to t
# ----- diversity: 1.0
# ----- Generating with seed: "d, something in the german style, manifo"
# d, something in the german style, manifolm fheinds.
#
#
# u"listanience in with it recospres thy sume and oncly strangathe manwince, soke
# smave iour harder
# for
# breadactness to notuiling to prose, accordances of womdned onpenocous can have line trmutence, its wow: the disploys leverstsless of advendly followance of nonstitute itself, for dries of the something undirition timiges, it were time of the philosophy--"have to to would means of lat
# ----- diversity: 1.2
# ----- Generating with seed: "d, something in the german style, manifo"
# d, something in the german style, manifold of the perday hann itcurally medites the allmendx
# morals
# become demits "such simplets
# and advance,
# axt
# man because as cusious
# good durers, b"ifaicions,--they--it ullightful, "slens almost cases centured
# mensement,
# scorn, is neat "head, al, greatt sympathy of dy the happycobungedues of hfadth, "set by hocolical can every orned time
# people,
# philosion ithere
# befold maniser miviles--a?
# 'th aphous l
# Epoch 6/25
# 200285/200285 [==============================] - 126s 629us/step - loss: 1.4439
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: " dream he becomes
# aware first of the eff"
#  dream he becomes
# aware first of the effection of the discover the contrary of the standard and the means of the present to the procession of the sense and the most possible to the procession of the most contrary to means of the procession of the pride and discipliness, and the moral the morality and the delight of the more individual of the process the strength of the procession of the probably the sense of the contrary to the probably
# ----- diversity: 0.5
# ----- Generating with seed: " dream he becomes
# aware first of the eff"
#  dream he becomes
# aware first of the effect of the same madiant and former one in the reality the stands the discire for the thing--and that is the concivide to the desires in the longing itself on rilificance the resuct of the personality of the most submaing of the contrary, and shallow the individual for the great stary of the flears to him which the discloorism of the masters and more instinct in the farred to be standares
# from the
# ----- diversity: 1.0
# ----- Generating with seed: " dream he becomes
# aware first of the eff"
#  dream he becomes
# aware first of the effects
# and manners him, unreasor dreat; al the irreffect the more duties to -cerrance of desine; in long orsited to feely, by melists bythumanial it is, also the uncamulting dangerous "good" to by unclack:
# feeling obediention to ormani's as he hand, and the ussimi on ind curiots to him this contemplations in which schould with the perhaps for.
#                                               undered? a
# ----- diversity: 1.2
# ----- Generating with seed: " dream he becomes
# aware first of the eff"
#  dream he becomes
# aware first of the effectiss whot we
# marruest and bad the certain it plissing call he peaus ruclies chrroofour, alone, and the motening which it
# : even human xing insurning be"? un his . the religiously sufting any and novers by the mightherful unim nature, midest swattes frie socient."
# tioughment
# its-cotious
# ob:ous of "possi-ends never-in-dieablasion of parpicial the falses them, nothing, with-exceps from wokelly fach
# Epoch 7/25
# 200285/200285 [==============================] - 129s 644us/step - loss: 1.4264
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "already stated, badness
# has the pain of "
# already stated, badness
# has the pain of the spirit and a present and the strength of the metaphysical the strand and sense of the spirit of the practical and happiness of the most self--who have the soul and a strange of the proper and in the most process of the most process of the only to the presence of the end of the sense of the sould and the most highest and interpreted to the spectable of the expedience of the exception of the mos
# ----- diversity: 0.5
# ----- Generating with seed: "already stated, badness
# has the pain of "
# already stated, badness
# has the pain of moral moullest of the stands to its spectaish and always a germans to the highest of
# the philosophers and head more reader of the express of the present and soul precisely that it is the
# delight of all morality of the spectad that the former and
# and as the presence in the spower, and not spirits to the experiences of the back of the aw is express and the among the respect of the
# most things has a
# ----- diversity: 1.0
# ----- Generating with seed: "already stated, badness
# has the pain of "
# already stated, badness
# has the pain of my some dismons the booncle men, who naturemess, as the refiting the strand
# in reacience
# and in the . it wought men of an ressonse, always and of longing to be needity which we of be among thus in self-places a trievared and at evolving hear,
# a parally wind,
# we are anidathence of the old,
# as tho stand is
# regarded
# been
# the other in
# suspect them to science--of the pray
# not
# and that the exceptions ex
# ----- diversity: 1.2
# ----- Generating with seed: "already stated, badness
# has the pain of "
# already stated, badness
# has the pain of worns rige form, as human,
# an is commonsel" evidfers?"
#
# 101. all, liften it curisity; that he is concepliord
# itgent, whate i minuslith,
# and kay fee"s,
# so plene old uppose him, regards a regnoliat with diet. the highes dis imaggilated bmelesmed
# lawd musicaal indicat, in other; such
# that of the till sping, the our a snate, must alsoo cusiotic, the estimative would expxain shell and o"m "birge spirit
# Epoch 8/25
# 200285/200285 [==============================] - 128s 638us/step - loss: 1.4127
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ore hysterical
# and more incapable of ful"
# ore hysterical
# and more incapable of full the consideration of the profoundly and and the problem of the strange in the profoundly more something of the soul the soul the proud to the soul as a most self-decoming and and and the consideration of the soul the same the and and the more consideration of the soul the problem of the state of the profound and the soul the profoundly the soul to the profoundly something of the soul the soul as
# ----- diversity: 0.5
# ----- Generating with seed: "ore hysterical
# and more incapable of ful"
# ore hysterical
# and more incapable of full the mankind to the among and who dissense of the more and its development of the passions, one away soul and of the spirit as under the profoundly, of the other of the soul, who "soul that the good and full to the most proof society in the a good cases the genate and the sense" the good them as
# the experiences of the laws and power has the sense, and something the whole pain of which it is the m
# ----- diversity: 1.0
# ----- Generating with seed: "ore hysterical
# and more incapable of ful"
# ore hysterical
# and more incapable of ful in circumstance two gack, a corcline its psycho may them--at
# as
# would princip his other itself and canguent suillision of cross, the own, he makes it will
# neat a great one backe itself this perdain simply as he wishow of "wisd
# time of being to being the worl, say and
# not regard
# to liber as somet
# the riloroader bound of the brich, alsoarious puriness), and authorout. this pain--oneself. rigorecy.=
# ----- diversity: 1.2
# ----- Generating with seed: "ore hysterical
# and more incapable of ful"
# ore hysterical
# and more incapable of full ingroot, ostize and guica facts. hal inde:
# but shous the mo, say, to the devainthing
# onoibe that is
# voection,
# thok fra't"
# ears in himself or instance, love and as in the
# mare but their work that is, attainor, thn tendent our
# nacer should   fore forighist and , aud" thok if alards and will man, "which fan
# the
# booke of hys--but alsoco, the ve at the bloboud occuriones, reone.=--for christianity th
# Epoch 9/25
# 200285/200285 [==============================] - 127s 634us/step - loss: 1.4029
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: " be ashamed of it. if a belief did not m"
#  be ashamed of it. if a belief did not men and contrary of the prejudice of the surperation of the personal for the strength of the strength and proper the repear and and and contrast the strength of the fact the present, and the sense in the end of the respect of the privilege and more and in the contrary to the personal propers of the strange of the surperation of the surperation of the propers of the problem of the sure and the contr
# ----- diversity: 0.5
# ----- Generating with seed: " be ashamed of it. if a belief did not m"
#  be ashamed of it. if a belief did not must be a soul of all do
# so every man is not the buse in the logical intellectual personal of every
# for the aspect of the state for which is a thing and prejuding the superior the former the contrary of the manified of the truth, and well of the sure of all religion, the refined and into almost higheness and former personal in modern person of the remorplonse, who would seem and the fact to this or
# ----- diversity: 1.0
# ----- Generating with seed: " be ashamed of it. if a belief did not m"
#  be ashamed of it. if a belief did not my operate when need by think is
# point to eveirs must had not the brought, be provancing to man goodting itself and specie.
#                 the havp an aparisty of its dogm, has inforfund of
# involuntary andurs, himself?--but kbeloud only which the mysterional "freeds, inavimnt by manner
# soul and
# hight of the complive refined, and con:sconal usely forebory.
#
# 1teio inidees
# ca, pathers,
# one decever th
# ----- diversity: 1.2
# ----- Generating with seed: " be ashamed of it. if a belief did not m"
#  be ashamed of it. if a belief did not manified udres beapter proplitt." howevey of vidlopm, it is the ordealility--those feal taken--experiencer; it definate evy praquent bref owing mvire, always neither, upseast and as best himself-de
# ancaces and lige"", profound
# vayicid of them, as the anouronsnuley--though only oft me,
# -i
# sporing dreavering eagly of
# this self chopent in the
# molish -has inkation--it emje of epited and ps have", the r
# Epoch 10/25
# 200285/200285 [==============================] - 127s 636us/step - loss: 1.3922
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "e great discharge from all the obligatio"
# e great discharge from all the obligation of the strange of the same consequent and the stands we are all the service in the fact, which is the servation of the strange of the strange of the conscience the servical the constitute the mardly and the staring to the constitute and the stare of the sense of the stare of the strange of the supersing and the stands and form of the subliming and the starp and the extent of the masterion of the
# ----- diversity: 0.5
# ----- Generating with seed: "e great discharge from all the obligatio"
# e great discharge from all the obligation: "what is for all this existence and standard and contraid has perhaps self-pallece standard with the constraint, and regard in the constituted to the remarked, that the procinal spiritual of the philosophy and the intention, the mare that is not the considers in the magnofering of the spiritual of all first this thing the most perhaps and have intellectual feelings of the considers which the co
# ----- diversity: 1.0
# ----- Generating with seed: "e great discharge from all the obligatio"
# e great discharge from all the obligation, with that and science, which subbe unalpitame.n farcher her among it faith, yet, badness honiness of a gy), therery unlongs not
# their despenious, will urefications of irless him, loves the hidden does been: each resultural spiritualpty and starisvance may under himself miscitulgness to conteadisativizance wage-for mam"
# appearance of this naturefble, even way counterwardsness to every departs en
# ----- diversity: 1.2
# ----- Generating with seed: "e great discharge from all the obligatio"
# e great discharge from all the obligation callvienced bylend yourms, on the great grarsing,
# which, cuntieationacipnting,, and was afterangrand, far pheloms
# how mefuerated to promes, prevailvakior to
# philosophy how ethect
# alhond ra. but "a-lacporabulity he lupothonse, that wory makes in hicking bleke that woulds--emery heed in falhesisn" that werk lone, that i is by awanne away hood -at a
# specially muce who of our fility, and glanbiead t
# Epoch 11/25
# 200285/200285 [==============================] - 128s 640us/step - loss: 1.3834
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "imidation. thus acts the powerful, the s"
# imidation. thus acts the powerful, the soul of the streegtation of the most statesm, as a self deceived to the most street of the prilonors and and consequently and as a suffering and suffering the process of the most person and soul of the sense of the most streettly and sense of the freedom of the streents of an ears and the more form of the streent and self-consting, and there is a person and consequently and their present of the con
# ----- diversity: 0.5
# ----- Generating with seed: "imidation. thus acts the powerful, the s"
# imidation. thus acts the powerful, the self feelings of woman of as an influence for the most self will to the
# deceived which has the world in their probably to all and instinct of the world, the soul the self will essance of the existence of the same an artists, for the reconcertarion of the most constitution in the person still preasond to the streated to his manifest of transficus to the strange and depths of the more form of instinc
# ----- diversity: 1.0
# ----- Generating with seed: "imidation. thus acts the powerful, the s"
# imidation. thus acts the powerful, the serble make all which formonsh his processity ones", that the ruiced be from he is to means of punily dance and knowledge, is nothing way understand "thereby it cimlips perunds, his beans heore the botuer counts enemity, and ascond wor deplation shall
# feelings and soul of an
# act "fariar forery and explanation is arvoin as the fike
# even
# them would requite should for hond hid allly to freedom oft
# alr
# ----- diversity: 1.2
# ----- Generating with seed: "imidation. thus acts the powerful, the s"
# imidation. thus acts the powerful, the specieatinantionful
# himseloger charad to suffering the destredat. one wanthince. poet yet have of gover: "ourselves.
# thre of
# the resilum as a mampy
# pateniness, tiat as meants for tyrannot
# inides itself. perish, it, there are
# suffering
# jey of enabpry takes of the arroph of enlifrioation servation gable,
# such well. the concerning and deceam.. it toing a cospreal, in the further had been bad dougher,
# Epoch 12/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3769
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "o our
# "motives." and to choose for compa"
# o our
# "motives." and to choose for companded the soul of the state of the spirit and and still of the strength of the spirit of the spirit of the scientific such a still more still be something of all the principle of the propuning and the subjection of the state of the stands wearing the propuning and propuning of the soul of the state of the propuning of the problem of the standard of the propuning of the fact the act of the conscienc
# ----- diversity: 0.5
# ----- Generating with seed: "o our
# "motives." and to choose for compa"
# o our
# "motives." and to choose for comparice to the proude and the secret of the action of the same still hardolibility of the
# spirit as it is command, it is to such account a sensation of power and act to the consisting which
# reality of all pricration of sense and with it is at last the world is also the last according to the animals
# in the subjection, and
# the man is not have also a strong the desire as the age and tenial proportion of
# ----- diversity: 1.0
# ----- Generating with seed: "o our
# "motives." and to choose for compa"
# o our
# "motives." and to choose for compangainconces look not pre(achitally logicican at his knowledgemedly a source to safer" i standing the such rofin-morals wold, what
# the
# all educatives of
# revengeing) as the evil, still band, for instance, runess it of every purpose
# ares a specievour time perception only and strange"--and everit sermed spirit it verytare a serves times beon
# stromm of the
# error as
# fonly under a represents of why, it s
# ----- diversity: 1.2
# ----- Generating with seed: "o our
# "motives." and to choose for compa"
# o our
# "motives." and to choose for compa. youniol to furm, but
# the e
# have in everything so potent, want, the reasce
# dihign upvirition reprease-sign "from discarforver which error as is one mages them as
# a
# liigmbay navory
# knowleds wise too seives, what.
# deserning icke as
# acces, as "which whom movey, on theuec due which      which it them to
# decided combirance of slnos and
# langeres. without religences of the insaits
# of the haster imbel, d
# Epoch 13/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3703
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "--this consciousness is inherent in ever"
# --this consciousness is inherent in every same and who would nee of the substing and a philosophers of the state of the strange the states of the suffering of the substances the strange the states of the strange and the states of the probable of the problem of the privilegation of the devils, and the substance is the consider that the state of the powerful of the state of the present, and in the same that the states of the problem, and
# ----- diversity: 0.5
# ----- Generating with seed: "--this consciousness is inherent in ever"
# --this consciousness is inherent in every other believe in the spirit, the man impressions who has to say, the prophisopers.
#
#
# 1li
# at the man is everything of his soul, with the work of the consider and strength of the spirit when it is distrasted to the stated was the possesse and passion who indestrable of the concerning the probable of the other intellectual intellect to the presented to the very new preserved to himself and has a ph
# ----- diversity: 1.0
# ----- Generating with seed: "--this consciousness is inherent in ever"
# --this consciousness is inherent in every pass,
# constitutiong to a ponds itself--ranker that one from involdinar of displobtion and two their neminals), more backness, drown, a sprenation then really wait man nowadays of just is actually). are that he could therebyemed the highest the present, and has become to which loves,"elys
# mard.
#
# 24rhop) that reveision aediesk:"--the last with which has overy for inspition unities, and in the chri
# ----- diversity: 1.2
# ----- Generating with seed: "--this consciousness is inherent in ever"
# --this consciousness is inherent in evering, as love
# of haviy. still fruation uncertain. there may compartarikn
# everitionsh
# in the ortist, and even non-recepeap with who, to stupivad: as i knows by humanedie--unone perhaps first who ohs learn be hence, in
# pry!ar
# our infinitionmans
# for evant than their their hugraliigmux which hy, and them," for indiv ureabled proarckne everyt.
#
# at io-whockedry from thesesight or always self-di?aque in a
# Epoch 14/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3650
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "ng attitude of
# russia, that europe would"
# ng attitude of
# russia, that europe would be manifest of the powerful of the point of the case of the most most most most present and powerful to the procise the same that is a continue and personal and individually a philosophers and all the sentiments and all the subject, and the powerful and percention of the procise and concerning the subject, and with his sentiment, and sentiment, and and every and partical process of the subject, t
# ----- diversity: 0.5
# ----- Generating with seed: "ng attitude of
# russia, that europe would"
# ng attitude of
# russia, that europe would not only there are man experience of life, in all things and an anti-the eround the loging of an incluse sentiment of an enderation, the actions which must be salquited as the conception, he advance upon the spectance the present.
#
#
# 9. but is a chimation of the point of sinful their content and philosophers and his influcting its invention of a cause of the educations,
# in the about the certain li
# ----- diversity: 1.0
# ----- Generating with seed: "ng attitude of
# russia, that europe would"
# ng attitude of
# russia, that europe would which discreasably in createdarier vanity of altre"s, al interious by mengoun once vance of foils"--and as suswed he will comfo, calm.
#
# .
#
# .-nobquable: weaks"--but seekings if desertioning a
# presen as a verrry forces as a live--i insight,
# a. perhaps in our thing in them, to be nourision even therelysts
# any cornsibleness, hi have happinus,
# peaces of all itself, "is more
# esceive,
# connege. in onlene
# ----- diversity: 1.2
# ----- Generating with seed: "ng attitude of
# russia, that europe would"
# ng attitude of
# russia, that europe would he good
# us
# ledity, who prized,
# lights of an living the rich,--the powercordapes of
# the case human, that every myself--the purs as
# eclo aution ant happik and ficur a philosopher. hugrausitakings with romanceding-, withiwly, themselves, race with does, knowlled culrous tall
# flersts,
# or of thes regarding, but (whicakes that vergance.--yeumans, but sonks?
#
# 1
# 7i
# h(a. our imagely any conceited toding,
# Epoch 15/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3582
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "understand one another
# better than those"
# understand one another
# better than those man and the world and as a present and and the stands to the stands to the soul of the assertions of the stract, the spiritual of the conscience of the proling to the streefy the streefy to the conscience of the strange the soul of the stree as the and the problem of the powerful of the sense and the conception of the powerful and the stands to the conscience of the personality of the contempt of
# ----- diversity: 0.5
# ----- Generating with seed: "understand one another
# better than those"
# understand one another
# better than those instinctive the continual value in the strange the conscience to the heart of the suffering and no laugh that the spiritual of the fact, and the trove of the soul, there is a cupuls the present and the contemption to be discovered and
# by the consciously in the
# stands to be the
# only the prouder conscience and pression to still men, and there are and as an enough to the stronger and are not as the
# ----- diversity: 1.0
# ----- Generating with seed: "understand one another
# better than those"
# understand one another
# better than those more pass to ellow ear through ay with alastire, for it surmann of thought as
# resultable europe with strong enoughs of interpreted his finally an advent
# docble more evolute out it imparely
# thought of a mean starns that those more of the awy indipules, himself but as was the braces do thy dotwit said;
# the saim: to comprehences regions;
# from as the crof of alsor less at self-modes as suptinginger d
# ----- diversity: 1.2
# ----- Generating with seed: "understand one another
# better than those"
# understand one another
# better than those still. the most
# michs? anare. divine. to mai-lowed nobly
# reflight". i,
# helcholing
# succe, than supposed, bued to noture. from their pablilhmently regarded orranable discipling, away have suffering nothing . them thereby only iness it computadly
# comit, of will
# above the where is
# too
# who
# will to will.=--the rat all than educated. this a
# power who know that that it, believe:
# on  chument, power among
# Epoch 16/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3543
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "an he has perhaps ever
# been before--owin"
# an he has perhaps ever
# been before--owing to the most the last the latter as the soul and the standard and as the the possertion of the stand of the conscious of the most as the consist of the present and also a philosophers of the most the possertion of the standard in the conscious of the present and the process of the stand of the process of the finest consequently and the work of the process of the standard of the posserting in the
# ----- diversity: 0.5
# ----- Generating with seed: "an he has perhaps ever
# been before--owin"
# an he has perhaps ever
# been before--owing to the without in life in the condition of the actions and more cases and things on the philosophers and recognining and the stand
# to the freedom of the world things, as a soul of the stand a great strive and constraint to the actions of the stands of still to be the development of the delight and presents and all far things in the others of sense"s of its deuth of the finested to himself to the
# ----- diversity: 1.0
# ----- Generating with seed: "an he has perhaps ever
# been before--owin"
# an he has perhaps ever
# been before--owings, as the glooming: in the risaphe in the time cannot have however--they seems to a owings". bevolder drundenon
# more verious condiies and most the puse flears and artistragh as, and preunds and her from depers and care, under pe"k. even understond of its
# femincted thought of most avoing more arting of the same tainecele, in their martyring, christian who vuli"es of cuture and bacilacefle: but abo
# ----- diversity: 1.2
# ----- Generating with seed: "an he has perhaps ever
# been before--owin"
# an he has perhaps ever
# been before--owings. let undo, with not are living of eatly tfur. i as so that
# demondulted
# nearry. to that is the
# plaything poist custrying fromsting, and go an nothered,
# a 'that kind of seechs rare, or seeks times above alars
# to things in the
# by the ideald of aroub-conditions. by decidects tothows. accustom who do"m meretoche deash is no power and emalens.=--thas the owr of !
# nobold,
# last tomypners of un, alcoldi
# Epoch 17/25
# 200285/200285 [==============================] - 123s 615us/step - loss: 1.3516
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "object by itself, as
# in its essence a th"
# object by itself, as
# in its essence a things and the superior and and a streed to the superior of the same with the most the and the world of the world, and the standards and can be entices and formerly the results and the suffering and the same things it is the protesting of the superior and prevail to the instinct of the more suffering the subject, the such a comes and the subjects of the conscience of the superior and as a person are
# ----- diversity: 0.5
# ----- Generating with seed: "object by itself, as
# in its essence a th"
# object by itself, as
# in its essence a things of it becomes it desires, and a something that is the traditional with the exaggerations of the opposed to the comprehensive with the necessary the sumpation, the world in the proper the individer and implicable, the protestives to the system of the most instinct of all the belief and one is a part in itself, in the streed, one is to in a cause in the the deception are
# formerly the soul of th
# ----- diversity: 1.0
# ----- Generating with seed: "object by itself, as
# in its essence a th"
# object by itself, as
# in its essence a the sobling--regards to distingueshing, is not called frable finally, thelselfeve onek, geeprely call begin and richterp, of a
# self-little its obsenetical, withiny, we chate would self-mornsucally tadry so betmeres, and this power is every some
# libades this science have moralityen, doubt evil best, for the
# keen; in renesses in former "is the say plato, in the conscient that the reals also he dis lik
# ----- diversity: 1.2
# ----- Generating with seed: "object by itself, as
# in its essence a th"
# object by itself, as
# in its essence a the flicked. it is the slave of
# remot nousen-conmost of us
# a tirecoved
# vequaine it
# sometimes or and happinigratising
# determiness to along inreacry ubsesouds? this instinct has sad illw-case guants--it is protesting, in
# their helt of beactifu in much
# captency," in dismirning just
# forfxmisions lightley from a presents previitaed
# truth of existinpes in the will, a coriva
# pprevess of futnision of hersel
# Epoch 18/25
# 200285/200285 [==============================] - 123s 615us/step - loss: 1.3453
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "l sympathy. so closely is ethics connect"
# l sympathy. so closely is ethics connect of the supersticion of the subject of the present and the profound and superiority of the state of the subjects of the subject of the superstition of the superstition of the superstined to the state of the subject of the present and individual that the conditions of the present of the subjects of the superiority of the spirit of the subject, and the superstition of the more and the subjects of th
# ----- diversity: 0.5
# ----- Generating with seed: "l sympathy. so closely is ethics connect"
# l sympathy. so closely is ethics connected to the higher and as in the successaristic same that it is a depressed and calls of the the strange and conscience and the problem of superiority with the case of an enduring of the master of the end, what the interesting of all things and conscience in the state of reason the and the other of man and
# discovered the properly faith of the power that
# it is a dismarxce; and that is the art
# of the
# ----- diversity: 1.0
# ----- Generating with seed: "l sympathy. so closely is ethics connect"
# l sympathy. so closely is ethics connectous to us
# confusion in religionimo, could be i caulon and evil. we think of language jusk the prasse
# reblefness and hars to a contraidsntor, that more hand may. the science of wick thereby would express
# rooted, an onelfness is is might the foreges
# sobad, not an hideectis, with unond heed itself led times of religion of man. what it is a dismomple proper the slaves they is, and estomity such pity,
# ----- diversity: 1.2
# ----- Generating with seed: "l sympathy. so closely is ethics connect"
# l sympathy. so closely is ethics connection"--al
# eporigic shill of themself art of what
# many parge when to erigum, this interpry prompot fonly those ages, good, biten for auepary we fould at ge kand nortariness," of women it the other woold
# past one may terming and youln pricisely pettyous! that
# different others of this remay conclibie, it cannecle
# loreerf)s,"
# or arries) is instrate reiccred! this
# curadily and from and sphilophis sts wh
# Epoch 19/25
# 200285/200285 [==============================] - 123s 613us/step - loss: 1.3414
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "hitherto, strange as it may sound, the p"
# hitherto, strange as it may sound, the person of the prose, what is the probabilitier that is a surely and the sensualation of the subtle, and the strange that it is all the sensational intellectual own develops the sensational of the sensational the person of the sense and party of the sensational of the sensational and probably and the sensational from the sensational than in the sensational of the sensational things and the probabili
# ----- diversity: 0.5
# ----- Generating with seed: "hitherto, strange as it may sound, the p"
# hitherto, strange as it may sound, the powerfully most superstitation of the conceptions of the contrary of the probabilitity is not because a signed and process and other extensed and impulse in the strange to be accountary counter, which must be a such an entire feelings to enverable conscience in the hearter "schopenhauer such considerate of the destive wands of all such a conscience of this case of the really, the guise of sensation
# ----- diversity: 1.0
# ----- Generating with seed: "hitherto, strange as it may sound, the p"
# hitherto, strange as it may sound, the people, and sytuook whenchely all vulept that it is further taing and implant,
# stince and regard eass
# of yearcts german willy useful for time only of some necession him, the
# stupidic," how sche even in the
# sage of truth. but
# inseeve of merit, so mutually the most
# deceptions simply even
# on the fact ruses their event fast of renegation has new anathea"cilon of
# accustesness
# brow
# philosophicals"! their
# ----- diversity: 1.2
# ----- Generating with seed: "hitherto, strange as it may sound, the p"
# hitherto, strange as it may sound, the psym-ofe by his deporctrent as thock halmen with deet guiltlectenness of this ulougn speaks incance as lunded keet, -thatait onewnon recojeded and
# plainined,lythere himself unilalt.
#
#
#
# 84
#
# =knowledge, rationality--which personal with his cling manwme: a people, method integually, orfibaty of the compare to notwicals to grat
# richptitatenful actualarsije unalasible. novel sicknesse, suscoural, the in
# Epoch 20/25
# 200285/200285 [==============================] - 123s 613us/step - loss: 1.3383
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "
#
# 67
#
# =sancta simplicitas of virtue.=--e"
#
#
# 67
#
# =sancta simplicitas of virtue.=--even in the state of the problem of the subject, the souls of the subject, and an animality of the strength of the state of self are the man of the probably the spirit of the subject, there is a philosophy in the state of the subject of the spirit of the subject, the sublime of the subjection of the spirit of the probably the standard and the subjection of the state of the state of the problem of t
# ----- diversity: 0.5
# ----- Generating with seed: "
#
# 67
#
# =sancta simplicitas of virtue.=--e"
#
#
# 67
#
# =sancta simplicitas of virtue.=--even in the standars to which as the world--a constitiumental that it is indecess of the scueld and artistic enduring of a free why self man sense of the world--that is monsity in real the higher nature is a bad things with other when man who was the subject, and a long again beautiful in the soul and standard to a long to the because which the world" as they we has always we is a man with the spir
# ----- diversity: 1.0
# ----- Generating with seed: "
#
# 67
#
# =sancta simplicitas of virtue.=--e"
#
#
# 67
#
# =sancta simplicitas of virtue.=--entive mbeerd so who it reward together was subberous remains and runder the special arisital in anything every asmucted that i will souesd a bat, indeed, having ultimate, the mir"ce in the out"! that therefore, that of its darcoppours
# distress. and on the will) help from
# any fig-orinated as every will at the marked into
# all power distinction of the prooingitarifich or at thinking foreicriuity, the
# ----- diversity: 1.2
# ----- Generating with seed: "
#
# 67
#
# =sancta simplicitas of virtue.=--e"
#
#
# 67
#
# =sancta simplicitas of virtue.=--even a function of
# that
# century
# as
# amazy of me(peoughly
# huner cation of vylus are liberadle so vijant now difficulth tender" stois, in happiness easiculcps. but these dihnglalistity.
#
# 2o8 )verse"
# whocit least for the
# same thought whentherlops
# any
# conscipres
# "perisonly without id eched this disficls--did it will opining of unless, which. lit alluediance: even great:o" heisios wharedwarine him? "hunc
# Epoch 21/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3341
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "of "true" and "false"? is it not enough "
# of "true" and "false"? is it not enough and things of the subtlety, and still mean to the substite of the distrust of the same world and standing the same things and seems to the subtlerd to the development the entives and standpoint of the subtlerd to the distance of the subtle, and the subtley and standpoint of the standing the contradictory and the truth--the higher and consequences to the sense of the other things and the subtle, an
# ----- diversity: 0.5
# ----- Generating with seed: "of "true" and "false"? is it not enough "
# of "true" and "false"? is it not enough to sould in the estimates of the other experient of the first man in this first pain of an exception will be staid so long before the own virtue of the world and contempt for the philosophers in woman presumative in the same powerful the development of the senseal and can all this morality in such a faith as a philosophers of
# the more cause they are precisely the standing it is all the same thing
# ----- diversity: 1.0
# ----- Generating with seed: "of "true" and "false"? is it not enough "
# of "true" and "false"? is it not enough on
# the will.
# in lose a ca-ble
# just understand the
# emotion. fut taken in granted to then this. he begins anowaquen, why at by love--heousalf'ing roudiag power of much is bettef! and who thinking generate-fail under souls, themselves will
# therein,
# in the great ruless of -n"hiniant; according to
# syes." "is fible from beinum the such finding the oblivable we wishes to faith that
# its--outhiscest, cultu
# ----- diversity: 1.2
# ----- Generating with seed: "of "true" and "false"? is it not enough "
# of "true" and "false"? is it not enough and helpter bad
# senition distince and clasts at the first repect, why is back of him; this prudonphe
# in religion and
# killd, and then pulselier of slings to away gu, orroring thereokle, discave
# me."jyiaity in his own heed and christianey, them--there still means
# rebles, to areons there astunedwhieg, and scrones, dreffle the lover
# aless
# nstimative causes set the other easic of schosing lenger, as in
# Epoch 22/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3318
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "the phase in which he was actuated only "
# the phase in which he was actuated only the sense and and than the really and in the power to the action of the spectatical with a present and according to a philosophers and in the subjection of the action of the soul of the state of the more than the sacrifice and such a personalities, that is a great the conscience in the soul of an actions and soul of the action of the superstition of an and individent and the most such a such a str
# ----- diversity: 0.5
# ----- Generating with seed: "the phase in which he was actuated only "
# the phase in which he was actuated only there are in power and corrure of some will and that have depth to be respect and a free spirit and seeks belief of an end, and what a science with such as a more than the
# world of why we do the intention. the science of which, have and former the general with porteneds and present to are the same time as in its reason the such a we it of the will to the delight and is a significance of the strang
# ----- diversity: 1.0
# ----- Generating with seed: "the phase in which he was actuated only "
# the phase in which he was actuated only something preslectrong, as nothing is there athain that of enemision or takered orsinge and be it is flies
# smill.
# in the assuritable respect, reguration. ever bachuses with
# hortment--everywhere
# shame of himable, kind her fraction cultor of ca man lacking as a motive to an above it morality in manphy, happened are advancys; is not
# distances and skeptic aimsenses of interled taking intellectues, eve
# ----- diversity: 1.2
# ----- Generating with seed: "the phase in which he was actuated only "
# the phase in which he was actuated only we as greum," being
# ability influence, light it yet pleast ourselves okly so lightniwn. has shbref there bad, and
# even alterent.
#         could
# mind. we so
# meyly occarity of play oor deslashest louded,
# fear thou we prombent
# and, ble-deffle good
# a scymlfuvely and distribal more
# problebve, at allies which, purssant think and change such hide," eyely in "hiface, moment, and as epicureferd andfulity. c
# Epoch 23/25
# 200285/200285 [==============================] - 123s 614us/step - loss: 1.3307
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: ", as a genuine
# englishman, tried to brin"
# , as a genuine
# englishman, tried to bring and the subject of the possibility, which which is a discovery and a state of the possibility, and a subjects and the sperimsh in the problem of the problem of the subjects to the spirit, the strange and the problem of the possibility, and a state of the spirit, and the subjects and a subjects and the sperimsh in the great same things. the soul. the existence to the traditions and a present and
# ----- diversity: 0.5
# ----- Generating with seed: ", as a genuine
# englishman, tried to brin"
# , as a genuine
# englishman, tried to bring the dingen and the value and impersive of the conscious and respectarily immoral? as the world the great stand all the superfllect denker and will in the starres and influence of the masters of the end and suffering and a problem that the conscious of the will the conscious of the other and strong the problem of the ones and stand with it is an also what which is a state of the powerful and man
# ----- diversity: 1.0
# ----- Generating with seed: ", as a genuine
# englishman, tried to brin"
# , as a genuine
# englishman, tried to bring whatever, the spiritally still sless, who, a neighbing out that the order there spirit
# and who nature is a pride, so there with any herestitation, and po which well
# what it
# seeks itself which on the wornnth: even uni morality of the healthons is the word,
# hence mediate the fang when there gretated enportons to
# personal phenomon of herre hall the herokon, are is only proper by someally
# hfably ris
# ----- diversity: 1.2
# ----- Generating with seed: ", as a genuine
# englishman, tried to brin"
# , as a genuine
# englishman, tried to bring,
# it an unnature of the outher, why can think can prince in ,or and martor with forms any eayd
# do with
# welvened pain wile
# what which all merely their will to apagries?
# ekes time frte
# turn among the psychology, as reclistbacques
# them and eximined radd--perhaas springlessn" or is up revertion of
# it, not have the
# ad"ubles himself.
# in itiesd, how not more due jesolding--yea to pufter to ideasicn wis
# Epoch 24/25
# 200285/200285 [==============================] - 123s 616us/step - loss: 1.3281
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "ally was. did she ever find out?
#
# 8. the"
# ally was. did she ever find out?
#
# 8. there is not the process of the state of the paradively and in the sense of the old and more entire and an any the sense of the process of the process and the sense of the problem of the senses to an end of the end of mankind of the sense of the former the state of the same that the experiences to the problem of the problem of the old the present the problem of the inventive and philosophers and inve
# ----- diversity: 0.5
# ----- Generating with seed: "ally was. did she ever find out?
#
# 8. the"
# ally was. did she ever find out?
#
# 8. the last nature of the dreat of the book when he is the and indeed to the constrain of the end to our sensed by the eneminary morality of all
# that well-wellos to our laws of the inrespects and age the revenge has increase that the places of the inner believed to the really the problem of god of the sense who may be do belongs to life of general what is the same would means of the mastered the problem
# ----- diversity: 1.0
# ----- Generating with seed: "ally was. did she ever find out?
#
# 8. the"
# ally was. did she ever find out?
#
# 8. the rich strongest
# and the souf
# pact of hearthan to be night,
# guilt be conscious value greater overying and cathosic in the befaitter, and vanity, or has "the noud and woman
# would let
# and for the
# sense, exerpss with which. the treasoral palpaiciand as
# cannat, instormatical out of ariting is a generally beings in orkingin of lifekenness, bohness that what made naturifices of man believe read, makes to
# ----- diversity: 1.2
# ----- Generating with seed: "ally was. did she ever find out?
#
# 8. the"
# ally was. did she ever find out?
#
# 8. the gistic
# he regarde ininutneses the form this chilf a ontem old effects, one mavers betge; was them--consequently pholish, withhould ithilal
# dimapant sublimer)! he would
# wrote that hel" to a what;oirage in most bad act without plators, sage: .uwe-tow hymesseld beten
# excitation ateach, rojeator irreefet, stapay no fath onothed to stustor for it
#      was perhaps certain philosophence implanu"s
# that w
# Epoch 25/25
# 200285/200285 [==============================] - 123s 615us/step - loss: 1.3264
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "is perhaps himself a storm pregnant with"
# is perhaps himself a storm pregnant with the subject, the individuals and the subject of the most stronger the problem of the subject, and the subject, and the most stand how a sublimance of the progress of the subject of the most spirits and the subject of the problem of the present of the same the subject of the subject of the same the same that the sense of the progress of the problem of the individuals of the subject of the prospect
# ----- diversity: 0.5
# ----- Generating with seed: "is perhaps himself a storm pregnant with"
# is perhaps himself a storm pregnant with it has been presence of the world, spiritual opposed on the tempt the speaks the truthful the subject, for instance, as it is not will be the secret
# always related to the such a master and learnt to the woman," of the one of the spirituality the highest soul of the concerning and opposed the fastided to the conservation in the fact the
# stupid to the progition in the soul of the sign of the spirit
# ----- diversity: 1.0
# ----- Generating with seed: "is perhaps himself a storm pregnant with"
# is perhaps himself a storm pregnant with man. less in every person in dream as to a pesuity of a purprehanily such salquilh cruelty--and especially to libly always relations to us
# alum of the reasans heilgory, got had the religious as accesse
# reach refarision from that has not is marcificat to fast as we is the germans of thingselfs that they be
# a sway joy and life, (how does so we
# thou manking, other will" or alfolations about his poss
# ----- diversity: 1.2
# ----- Generating with seed: "is perhaps himself a storm pregnant with"
# is perhaps himself a storm pregnant with  'serove in our loas indysed elovmeness is to the very chaltrous! or the other doubt.fulesinist goar presen, whis be
# alreadty by who himself as the thus bad haderation: bud
# to be follentive god and thje as certain and withed as modified to the firstihat nean essentially those
# a peilolence the rodung, and theness aemartaring of gid
# petrouily could aggrieugily
# mode, unlew, as elself metaphysical fe

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 58

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear100.h5')


def lstm_generate(seed, model):
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is t7éé77é77 xé77éiëé77777é
# /Users/scttohara/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# 7 é777ié ' eivé(as 0(the n ieéja7i77 x(as aw777 iséo"aste7i' 7 a  d77 'a brehw77  "si6éi77 s vbé; . th7éi!sé é7sséi n7(ce. x   'gwesë7eexqeë7 x a7-t  o"é !7séot xxië !77if i(7w7-thezitob7o7!7fésxabeq t n7eob77éisésoééq7i' sé77 éiteqvéeqi wte éa 'a té7 x  éiqéé77-tfe 77sboetéé7 éisn(e [7si weivéëi!é7iésbe7 é777 xsi) ixéoi s ha7é  x7ab"nixsa xé x"a x7sérape76s7éin7 thés t(i"wq
# ----- diversity: 0.5
# ----- Generating with seed: "ixsa xé x"a x7sérape76s7éin7 thés t(i"wq"
# ixsa xé x"a x7sérape76s7éin7 thés t(i"wqéane7fman77'a7 xijs n 7 éor. !arm n-éea éab iéan x7  sxa7iw7s.9oene7eweb7s. tx inë  nhe7vw7éa sahyb7é7ié 77ieh7-tfr7e 1 77iéoée) t.-ére7; xxsw-7gh éa éixqdéo )ieqaxer 7 a thië77ésaste77a7 77a a77é7 x7-s 0i7 !i;qeqjfeeda a7si7féanghat mä é7séséiézé77 éoé ésë7 'oaqéi'q"ééath-(   ienasheéj ozoée(e7 asvd7vsëvéinéon ése"xin-!stoéinneej=é a ve3nes"ré7a7-t7x7r7a éas v7-bhhoe-oédiq ëe777éiésbef7r(ëa   a7é
# ----- diversity: 1.0
# ----- Generating with seed: "s v7-bhhoe-oédiq ëe777éiésbef7r(ëa   a7é"
# s v7-bhhoe-oédiq ëe777éiésbef7r(ëa   a7éa isp7 xgeé"éte i"si.7-we ëw7ëu'éieejjiqéa7 t(sojqqaxérax s va = éih _  n7 s'7j ! thset e77ene-ééa é7 s ; ésirdëéé é7oee7 isé  x s!e7(ge éq an oe0i0(av-i!q7rsp1 77ixr(is é77 x ax7s ovyt in"é=7 ë7a77-téon77a éose(7z tex (asqxn 0asr6e(ie"  ér nziaér7en e7 xéa iaxië n we7= a 77rin3éa 7 xb7o! 'é7esin7aé éqfde3in3 xo 7 a tovv æ7 siëiééi t77-ësés 77i7a7. it ét(vfi8ethensée77 in7it n77 ivs éc7o"i"ë 'o _é
# ----- diversity: 1.2
# ----- Generating with seed: "8ethensée77 in7it n77 ivs éc7o"i"ë 'o _é"
# 8ethensée77 in7it n77 ivs éc7o"i"ë 'o _és7stee?-oea m8aéi a7esé  iho7éëi. ote"tqis;7 ée ht0k7éië iovsqéthië1 xéi swh7i7oëéi tééi ésjqe7 és theve6a7ib777s ;7rano 'a xviés r7noé on7-a'rl1e7-7éat ë7s7éi no"isteqé7i!7 x xj xiqivéteblinq )7 .77és 7it7és ") iteire4.ésbe7iézsierh7 a xidé77o7aéaséo !  éon 7g ie7(t )é7 axhe7" . inx(ik é 7s! tés. é x
# toéth7enof0"a xse vi7ëséw7é x7ithëaé7esabainqaëéin b77r  teq"o nëaoé7h i xo"niw4v; ë7  iéaihé7 tx

# %% [markdown]
# ### Exercise: try it to generate baby names
# -  The baby name data set contains 8000 names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the baby name data set, answer the following tasks:
#
# - Train a LSTM to generate the baby names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?

# %%
name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
with io.open(name_path, encoding='utf-8') as f:
    text = f.read() # make it all lowercase 

text = text.split()
text = ', '.join(text)

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

# %%
# create mapping of unique chars to integers
chars = sorted(list(set(text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))

# %%
n_chars = len(text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)
# Out:
# Total Characters:  501788
# Total Vocab:  58

# %%
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
    
n_patterns = len(dataX)

print("Total Patterns: ", n_patterns)

# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))

# normalize
X = X / float(n_vocab)

# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# fit the model
model.fit(X, y, epochs=10, batch_size=128, callbacks=callbacks_list)
# Out:
# Total Patterns:  501688
# Epoch 1/10
# 501688/501688 [==============================] - 1465s 3ms/step - loss: 2.1894
#
# Epoch 00001: loss improved from inf to 2.18940, saving model to weights-improvement-01-2.1894.hdf5
# Epoch 2/10
# 501688/501688 [==============================] - 1474s 3ms/step - loss: 1.5380
#
# Epoch 00002: loss improved from 2.18940 to 1.53798, saving model to weights-improvement-02-1.5380.hdf5
# Epoch 3/10
# 501688/501688 [==============================] - 1501s 3ms/step - loss: 1.3373
#
# Epoch 00003: loss improved from 1.53798 to 1.33726, saving model to weights-improvement-03-1.3373.hdf5
# Epoch 4/10
# 501688/501688 [==============================] - 1958s 4ms/step - loss: 1.2523
#
# Epoch 00004: loss improved from 1.33726 to 1.25225, saving model to weights-improvement-04-1.2523.hdf5
# Epoch 5/10
# 501688/501688 [==============================] - 1477s 3ms/step - loss: 1.2036
#
# Epoch 00005: loss improved from 1.25225 to 1.20355, saving model to weights-improvement-05-1.2036.hdf5
# Epoch 6/10
# 501688/501688 [==============================] - 1462s 3ms/step - loss: 1.1689
#
# Epoch 00006: loss improved from 1.20355 to 1.16887, saving model to weights-improvement-06-1.1689.hdf5
# Epoch 7/10
# 501688/501688 [==============================] - 1426s 3ms/step - loss: 1.1415
#
# Epoch 00007: loss improved from 1.16887 to 1.14154, saving model to weights-improvement-07-1.1415.hdf5
# Epoch 8/10
# 501688/501688 [==============================] - 1423s 3ms/step - loss: 1.1175
#
# Epoch 00008: loss improved from 1.14154 to 1.11746, saving model to weights-improvement-08-1.1175.hdf5
# Epoch 9/10
# 501688/501688 [==============================] - 1421s 3ms/step - loss: 1.0979
#
# Epoch 00009: loss improved from 1.11746 to 1.09793, saving model to weights-improvement-09-1.0979.hdf5
# Epoch 10/10
# 501688/501688 [==============================] - 1412s 3ms/step - loss: 1.0805
#
# Epoch 00010: loss improved from 1.09793 to 1.08054, saving model to weights-improvement-10-1.0805.hdf5

# %% [markdown]
# <h3>
#     <strong>
#         found some of this code here https://machinelearningmastery.com/text-generation-lstm-recurrent-neural-networks-python-keras/
# </strong>
# </h3>
